# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
car_rental=pd.read_csv("dataset/car rental dataset.csv")

# %%
car_rental.head()
# Out:
#    Car_ID          Brand   Model    Year Fuel_Type Transmission      Price  \
# 0       1         Toyota  Innova  2024.0       CNG       Manual  2020000.0
# 1       2            Kia     EV6  2023.0    Diesel       Manual  1770000.0
# 2       3  Maruti Suzuki   Dzire  2016.0    Petrol       Manual  3430000.0
# 3       4          Honda   Amaze  2019.0    Petrol       Manual  1610000.0
# 4       5          Honda    City  2015.0  Electric       Manual  1840000.0
#
#    Mileage  Engine_CC  Seating_Capacity  Service_Cost  Color Owner_Type  \
# 0     27.3      800.0               4.0       24100.0  Green     Second
# 1     16.4     2500.0               7.0       18800.0   Blue      Third
# 2     17.6     2000.0               6.0       24700.0   Grey      First
# 3     19.2     2500.0               6.0       23300.0  Green     Second
# 4     15.8     1000.0               5.0        5800.0    Red     Second
#
#         State Insurance_Status Manufacturing_Plant  Number_of_Repairs  \
# ...

# %%
#selecting features

# %%
car_rental.columns
# Out:
# Index(['Car_ID', 'Brand', 'Model', 'Year', 'Fuel_Type', 'Transmission',
#        'Price', 'Mileage', 'Engine_CC', 'Seating_Capacity', 'Service_Cost',
#        'Color', 'Owner_Type', 'State', 'Insurance_Status',
#        'Manufacturing_Plant', 'Number_of_Repairs', 'Previous_Accidents',
#        'Body_Type'],
#       dtype='str')

# %%
car_rental.drop(['Price','Seating_Capacity', 'Service_Cost','Color', 'Owner_Type', 'State', 'Insurance_Status',
       'Manufacturing_Plant', 'Number_of_Repairs', 'Previous_Accidents'],inplace=True,axis=1)

# %%
car_rental.columns
# Out:
# Index(['Car_ID', 'Brand', 'Model', 'Year', 'Fuel_Type', 'Transmission',
#        'Mileage', 'Engine_CC', 'Body_Type'],
#       dtype='str')

# %%
car_rental.head(10)
# Out:
#    Car_ID          Brand   Model    Year Fuel_Type Transmission  Mileage  \
# 0       1         Toyota  Innova  2024.0       CNG       Manual     27.3
# 1       2            Kia     EV6  2023.0    Diesel       Manual     16.4
# 2       3  Maruti Suzuki   Dzire  2016.0    Petrol       Manual     17.6
# 3       4          Honda   Amaze  2019.0    Petrol       Manual     19.2
# 4       5          Honda    City  2015.0  Electric       Manual     15.8
# 5       6            Kia   Sonet  2020.0    Petrol       Manual     21.5
# 6       7         Toyota  Glanza  2019.0       CNG       Manual     29.7
# 7       8     Volkswagen  Taigun  2017.0       CNG       Manual     20.2
# 8       9        Renault   Lodgy  2015.0    Petrol       Manual     10.5
# 9      10            Kia     EV6  2019.0       CNG    Automatic     16.1
#
#    Engine_CC    Body_Type
# 0      800.0        Sedan
# 1     2500.0  Convertible
# 2     2000.0        Sedan
# 3     2500.0  Convertible
# 4     1000.0    Hatchback
# ...

# %%
car_rental["Brand"].unique()
# Out:
# <StringArray>
# [       'Toyota',           'Kia', 'Maruti Suzuki',         'Honda',
#     'Volkswagen',       'Renault',      'Mahindra',   'Tata Motors',
#          'Skoda',       'Hyundai',             nan]
# Length: 11, dtype: str

# %%
car_rental["Model"].unique()
# Out:
# <StringArray>
# [       'Innova',           'EV6',         'Dzire',         'Amaze',
#           'City',         'Sonet',        'Glanza',        'Taigun',
#          'Lodgy',          'Jazz',         'Civic',         'Kiger',
#        'Scorpio',         'Punch',      'Fortuner',        'Kushaq',
#          'Tiago',        'Superb',         'Camry',        'XUV700',
#              nan,        'Ertiga',        'Altroz',       'Harrier',
#       'Carnival',          'Polo',         'Swift',         'Verna',
#         'Slavia',         'Nexon',        'Virtus',        'Tiguan',
#        'Octavia',        'Seltos',        'Bolero',          'Thar',
#            'i10',         'Venue',         'Rapid',         'Creta',
#           'WR-V',        'XUV300',           'i20', 'Urban Cruiser',
#          'Vento',        'Baleno',        'Carens',          'Kwid',
#         'Duster',        'Triber',        'WagonR']
# Length: 51, dtype: str

# %%
car_rental.describe()
# Out:
#             Car_ID         Year      Mileage    Engine_CC
# count  10000.00000  9995.000000  9995.000000  9993.000000
# mean    5000.50000  2019.544372    19.971056  1542.199540
# std     2886.89568     2.877338     5.777498   557.532169
# min        1.00000  2015.000000    10.000000   800.000000
# 25%     2500.75000  2017.000000    14.900000  1000.000000
# 50%     5000.50000  2020.000000    20.000000  1500.000000
# 75%     7500.25000  2022.000000    25.000000  2000.000000
# max    10000.00000  2024.000000    30.000000  2500.000000

# %% [markdown]
# Data Cleaning

# %%
car_rental.isna().value_counts()
# Out:
# Car_ID  Brand  Model  Year   Fuel_Type  Transmission  Mileage  Engine_CC  Body_Type
# False   False  False  False  False      False         False    False      False        9964
#                                                                True       False           7
#                                         True          False    False      False           6
#                              True       False         False    False      False           6
#                              False      False         True     False      False           5
#                       True   False      False         False    False      False           5
#                True   False  False      False         False    False      False           3
#         True   False  False  False      False         False    False      False           3
#         False  False  False  False      False         False    False      True            1
# Name: count, dtype: int64

# %%
a=car_rental.duplicated()
print(a.sum())
# Out:
# 0

# %%
null_rows = car_rental[car_rental.isnull().any(axis=1)]
null_rows
# Out:
#       Car_ID          Brand     Model    Year Fuel_Type Transmission  Mileage  \
# 24        25         Toyota       NaN  2020.0  Electric    Automatic     16.5
# 100      101         Toyota    Innova  2020.0    Diesel          NaN     29.9
# 105      106    Tata Motors       NaN  2015.0    Petrol       Manual     28.8
# 109      110            Kia    Carens  2022.0       NaN       Manual     23.5
# 174      175  Maruti Suzuki    Ertiga  2016.0       CNG          NaN     19.5
# 371      372        Renault     Kiger  2015.0       NaN       Manual     12.7
# 464      465         Toyota    Glanza  2015.0       CNG       Manual     19.4
# 498      499        Renault      Kwid  2019.0       CNG    Automatic      NaN
# 536      537            NaN     Sonet  2022.0    Diesel       Manual     28.4
# 705      706  Maruti Suzuki    Ertiga  2019.0       NaN    Automatic     16.7
# 765      766        Renault     Lodgy  2015.0       CNG       Manual     13.0
# ...

# %%
categories=car_rental.select_dtypes(include=['str']).columns
categories
# Out:
# Index(['Brand', 'Model', 'Fuel_Type', 'Transmission', 'Body_Type'], dtype='str')

# %%
car_rental[['Brand', 'Model', 'Fuel_Type', 'Transmission', 'Body_Type']].isnull().sum()
# Out:
# Brand           3
# Model           3
# Fuel_Type       6
# Transmission    6
# Body_Type       1
# dtype: int64

# %%
for i in categories:
    car_rental[i]=car_rental[i].fillna("N/A")

# %%
car_rental.isna().sum()
# Out:
# Car_ID          0
# Brand           0
# Model           0
# Year            5
# Fuel_Type       0
# Transmission    0
# Mileage         5
# Engine_CC       7
# Body_Type       0
# dtype: int64

# %%
numeric=car_rental.select_dtypes(include=['float'])
numeric
# Out:
#         Year  Mileage  Engine_CC
# 0     2024.0     27.3      800.0
# 1     2023.0     16.4     2500.0
# 2     2016.0     17.6     2000.0
# 3     2019.0     19.2     2500.0
# 4     2015.0     15.8     1000.0
# ...      ...      ...        ...
# 9995  2021.0     24.9     2500.0
# 9996  2024.0     21.4     1000.0
# 9997  2020.0     27.0     1200.0
# 9998  2020.0     24.3     1800.0
# 9999  2018.0     21.5     1200.0
#
# [10000 rows x 3 columns]

# %%
for i in numeric:
    car_rental[i]=car_rental[i].fillna(car_rental[i].median())

# %%
car_rental
# Out:
#       Car_ID          Brand          Model    Year Fuel_Type Transmission  \
# 0          1         Toyota         Innova  2024.0       CNG       Manual
# 1          2            Kia            EV6  2023.0    Diesel       Manual
# 2          3  Maruti Suzuki          Dzire  2016.0    Petrol       Manual
# 3          4          Honda          Amaze  2019.0    Petrol       Manual
# 4          5          Honda           City  2015.0  Electric       Manual
# ...      ...            ...            ...     ...       ...          ...
# 9995    9996    Tata Motors         Altroz  2021.0       CNG    Automatic
# 9996    9997          Honda           WR-V  2024.0    Diesel    Automatic
# 9997    9998       Mahindra         XUV300  2020.0  Electric       Manual
# 9998    9999        Renault         Duster  2020.0    Diesel       Manual
# 9999   10000         Toyota  Urban Cruiser  2018.0       CNG    Automatic
#
#       Mileage  Engine_CC    Body_Type
# 0        27.3      800.0        Sedan
# ...

# %%
car_rental.to_csv(
    "dataset/car_rental_cleaned.csv",
    index=False
)
